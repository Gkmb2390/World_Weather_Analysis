# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#create random latitude and longitude sets
lats = np.random.uniform(low=-90.000,high=90.000, size = 2000)
lngs = np.random.uniform(low=-180.000,high=180.000, size = 2000)
lat_lngs = zip(lats, lngs)

# %%
#Adding combined lat & long to list
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 783

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
        # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 1 | soltsy
# Processing Record 4 of Set 1 | norman wells
# Processing Record 5 of Set 1 | touros
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | airai
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | dubbo
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | te anau
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | coquimbo
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | geraldton
# Processing Record 20 of Set 1 | port augusta
# Processing Record 21 of Set 1 | chulym
# Processing Record 22 of Set 1 | terrace
# Processing Record 23 of Set 1 | muros
# Processing Record 24 of Set 1 | maldonado
# Processing Record 25 of Set 1 | rio grande
# Processing Record 26 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 1 | hami
# Processing Record 28 of Set 1 | jackson
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | barcelona
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | kahului
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | gumrak
# Processing Record 35 of Set 1 | dubrovytsya
# Processing Record 36 of Set 1 | sioux city
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | bengkulu
# Processing Record 39 of Set 1 | wanning
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | kaitangata
# Processing Record 42 of Set 1 | shimoda
# Processing Record 43 of Set 1 | cabo san lucas
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | ukiah
# Processing Record 46 of Set 1 | trelew
# Processing Record 47 of Set 1 | novo selo
# Processing Record 48 of Set 1 | hasaki
# Processing Record 49 of Set 1 | portland
# Processing Record 50 of Set 1 | oranjestad
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 2 of Set 2 | vostok
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | mandurah
# Processing Record 6 of Set 2 | georgetown
# Processing Record 7 of Set 2 | dalianwan
# Processing Record 8 of Set 2 | wajid
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | labuhan
# Processing Record 11 of Set 2 | anshun
# Processing Record 12 of Set 2 | villa del rosario
# Processing Record 13 of Set 2 | nikolskoye
# Processing Record 14 of Set 2 | berlevag
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 17 of Set 2 | mehamn
# Processing Record 18 of Set 2 | aitape
# Processing Record 19 of Set 2 | gat
# Processing Record 20 of Set 2 | ilulissat
# Processing Record 21 of Set 2 | meulaboh
# Processing Record 22 of Set 2 | uyuni
# Processing Record 23 of Set 2 | hitchin
# Processing Record 24 of Set 2 | maragogi
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | hobart
# Processing Record 27 of Set 2 | bredasdorp
# Processing Record 28 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 2 | sechura
# Processing Record 30 of Set 2 | bambous virieux
# Processing Record 31 of Set 2 | tasiilaq
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | galle
# Processing Record 36 of Set 2 | longyearbyen
# Processing Record 37 of Set 2 | cidreira
# Processing Record 38 of Set 2 | huambo
# Processing Record 39 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 2 | hithadhoo
# Processing Record 41 of Set 2 | alugan
# Processing Record 42 of Set 2 | anadyr
# Processing Record 43 of Set 2 | bluff
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | komsomolskiy
# Processing Record 46 of Set 2 | fort nelson
# Processing Record 47 of Set 2 | altay
# Processing Record 48 of Set 2 | zhaozhou
# Processing Record 49 of Set 2 | bandarbeyla
# Processing Record 50 of Set 2 | anloga
# Processing Record 1 of Set 3 | iqaluit
# Processing Record 2 of Set 3 | beisfjord
# Processing Record 3 of Set 3 | weligama
# Processing Record 4 of Set 3 | jiblah
# Processing Record 5 of Set 3 | dolores
# Processing Record 6 of Set 3 | chokurdakh
# Processing Record 7 of Set 3 | takoradi
# Processing Record 8 of Set 3 | hilo
# Processing Record 9 of Set 3 | russellville
# Processing Record 10 of Set 3 | cape town
# Processing Record 11 of Set 3 | nong ki
# Processing Record 12 of Set 3 | saskylakh
# Processing Record 13 of Set 3 | chalus
# Processing Record 14 of Set 3 | novyye burasy
# Processing Record 15 of Set 3 | villarrica
# Processing Record 16 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 3 | ayna
# Processing Record 18 of Set 3 | port lincoln
# Processing Record 19 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 20 of Set 3 | boden
# Processing Record 21 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 3 | vila franca do campo
# Processing Record 23 of Set 3 | taoudenni
# Processing Record 24 of Set 3 | nyurba
# Processing Record 25 of Set 3 | dondo
# Processing Record 26 of Set 3 | arraial do cabo
# Processing Record 27 of Set 3 | boda
# Processing Record 28 of Set 3 | hamilton
# Processing Record 29 of Set 3 | peterhead
# Processing Record 30 of Set 3 | russell
# Processing Record 31 of Set 3 | vanimo
# Processing Record 32 of Set 3 | takab
# Processing Record 33 of Set 3 | port elizabeth
# Processing Record 34 of Set 3 | hualmay
# Processing Record 35 of Set 3 | manta
# Processing Record 36 of Set 3 | bumba
# Processing Record 37 of Set 3 | iquique
# Processing Record 38 of Set 3 | qaanaaq
# Processing Record 39 of Set 3 | svetlogorsk
# Processing Record 40 of Set 3 | cherskiy
# Processing Record 41 of Set 3 | lavrentiya
# Processing Record 42 of Set 3 | raudeberg
# Processing Record 43 of Set 3 | nailsea
# Processing Record 44 of Set 3 | severo-kurilsk
# Processing Record 45 of Set 3 | kayankulam
# Processing Record 46 of Set 3 | laurel
# Processing Record 47 of Set 3 | mount gambier
# Processing Record 48 of Set 3 | tilichiki
# Processing Record 49 of Set 3 | limoux
# Processing Record 50 of Set 3 | khanpur
# Processing Record 1 of Set 4 | ambon
# Processing Record 2 of Set 4 | milkovo
# Processing Record 3 of Set 4 | ostersund
# Processing Record 4 of Set 4 | tiksi
# Processing Record 5 of Set 4 | alice springs
# Processing Record 6 of Set 4 | santiago del estero
# Processing Record 7 of Set 4 | kinkala
# Processing Record 8 of Set 4 | melilla
# Processing Record 9 of Set 4 | shingu
# Processing Record 10 of Set 4 | burica
# City not found. Skipping...
# Processing Record 11 of Set 4 | new norfolk
# Processing Record 12 of Set 4 | rawson
# Processing Record 13 of Set 4 | alanya
# Processing Record 14 of Set 4 | flinders
# Processing Record 15 of Set 4 | upernavik
# Processing Record 16 of Set 4 | half moon bay
# Processing Record 17 of Set 4 | antalaha
# Processing Record 18 of Set 4 | kavieng
# Processing Record 19 of Set 4 | pevek
# Processing Record 20 of Set 4 | qandala
# Processing Record 21 of Set 4 | ucluelet
# Processing Record 22 of Set 4 | chuy
# Processing Record 23 of Set 4 | blessington
# Processing Record 24 of Set 4 | simao
# Processing Record 25 of Set 4 | tazovskiy
# Processing Record 26 of Set 4 | chico
# Processing Record 27 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 4 | ancud
# Processing Record 29 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 4 | hauknes
# Processing Record 31 of Set 4 | fare
# Processing Record 32 of Set 4 | kabalo
# Processing Record 33 of Set 4 | pervoye maya
# Processing Record 34 of Set 4 | ponta delgada
# Processing Record 35 of Set 4 | srandakan
# Processing Record 36 of Set 4 | calvillo
# Processing Record 37 of Set 4 | cap malheureux
# Processing Record 38 of Set 4 | fairbanks
# Processing Record 39 of Set 4 | erzin
# Processing Record 40 of Set 4 | victoria
# Processing Record 41 of Set 4 | bafia
# Processing Record 42 of Set 4 | madimba
# Processing Record 43 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 4 | itoman
# Processing Record 45 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 46 of Set 4 | camacupa
# Processing Record 47 of Set 4 | baherden
# Processing Record 48 of Set 4 | ponta do sol
# Processing Record 49 of Set 4 | narsaq
# Processing Record 50 of Set 4 | hermanus
# Processing Record 1 of Set 5 | cheyenne
# Processing Record 2 of Set 5 | coahuayana
# Processing Record 3 of Set 5 | san policarpo
# Processing Record 4 of Set 5 | tezu
# Processing Record 5 of Set 5 | scottsbluff
# Processing Record 6 of Set 5 | taseyevo
# Processing Record 7 of Set 5 | rincon
# Processing Record 8 of Set 5 | nishihara
# Processing Record 9 of Set 5 | acapulco
# Processing Record 10 of Set 5 | nelson bay
# Processing Record 11 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 5 | luderitz
# Processing Record 13 of Set 5 | tuatapere
# Processing Record 14 of Set 5 | kununurra
# Processing Record 15 of Set 5 | aden
# Processing Record 16 of Set 5 | makakilo city
# Processing Record 17 of Set 5 | souillac
# Processing Record 18 of Set 5 | illapel
# Processing Record 19 of Set 5 | popondetta
# Processing Record 20 of Set 5 | suntar
# Processing Record 21 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 5 | nemuro
# Processing Record 23 of Set 5 | kisoro
# Processing Record 24 of Set 5 | faanui
# Processing Record 25 of Set 5 | whyalla
# Processing Record 26 of Set 5 | lasa
# Processing Record 27 of Set 5 | great yarmouth
# Processing Record 28 of Set 5 | cesme
# Processing Record 29 of Set 5 | dingle
# Processing Record 30 of Set 5 | tiarei
# Processing Record 31 of Set 5 | provideniya
# Processing Record 32 of Set 5 | la grande
# Processing Record 33 of Set 5 | olinda
# Processing Record 34 of Set 5 | madang
# Processing Record 35 of Set 5 | teguldet
# Processing Record 36 of Set 5 | miltenberg
# Processing Record 37 of Set 5 | lagos
# Processing Record 38 of Set 5 | buala
# Processing Record 39 of Set 5 | luangwa
# Processing Record 40 of Set 5 | juneau
# Processing Record 41 of Set 5 | xacmaz
# Processing Record 42 of Set 5 | socorro
# Processing Record 43 of Set 5 | rona de sus
# Processing Record 44 of Set 5 | khatanga
# Processing Record 45 of Set 5 | balykshi
# Processing Record 46 of Set 5 | san andres
# Processing Record 47 of Set 5 | mezen
# Processing Record 48 of Set 5 | sapao
# City not found. Skipping...
# Processing Record 49 of Set 5 | lemesos
# City not found. Skipping...
# Processing Record 50 of Set 5 | torbay
# Processing Record 1 of Set 6 | saint-pierre
# Processing Record 2 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 6 | turan
# Processing Record 4 of Set 6 | nanakuli
# Processing Record 5 of Set 6 | junction city
# Processing Record 6 of Set 6 | kijang
# Processing Record 7 of Set 6 | laguna
# Processing Record 8 of Set 6 | ilovlya
# Processing Record 9 of Set 6 | andenes
# Processing Record 10 of Set 6 | ilembo
# Processing Record 11 of Set 6 | codrington
# Processing Record 12 of Set 6 | auki
# Processing Record 13 of Set 6 | oktyabrskoye
# Processing Record 14 of Set 6 | east london
# Processing Record 15 of Set 6 | peniche
# Processing Record 16 of Set 6 | vredendal
# Processing Record 17 of Set 6 | waipawa
# Processing Record 18 of Set 6 | varena
# Processing Record 19 of Set 6 | santa maria
# Processing Record 20 of Set 6 | san patricio
# Processing Record 21 of Set 6 | mokrous
# Processing Record 22 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 24 of Set 6 | korla
# Processing Record 25 of Set 6 | broken hill
# Processing Record 26 of Set 6 | matay
# Processing Record 27 of Set 6 | bethel
# Processing Record 28 of Set 6 | bonthe
# Processing Record 29 of Set 6 | la ronge
# Processing Record 30 of Set 6 | apatou
# Processing Record 31 of Set 6 | chapais
# Processing Record 32 of Set 6 | helong
# Processing Record 33 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 6 | kingston
# Processing Record 35 of Set 6 | sambava
# Processing Record 36 of Set 6 | karratha
# Processing Record 37 of Set 6 | saldanha
# Processing Record 38 of Set 6 | penzance
# Processing Record 39 of Set 6 | kenai
# Processing Record 40 of Set 6 | krasnoselkup
# Processing Record 41 of Set 6 | mersing
# Processing Record 42 of Set 6 | riyadh
# Processing Record 43 of Set 6 | warrington
# Processing Record 44 of Set 6 | matamoros
# Processing Record 45 of Set 6 | platonovka
# Processing Record 46 of Set 6 | cabra
# Processing Record 47 of Set 6 | ambanja
# Processing Record 48 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 6 | khani
# Processing Record 50 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 7 | pangai
# Processing Record 2 of Set 7 | paamiut
# Processing Record 3 of Set 7 | yerbogachen
# Processing Record 4 of Set 7 | hambantota
# Processing Record 5 of Set 7 | tshikapa
# Processing Record 6 of Set 7 | sorland
# Processing Record 7 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 8 of Set 7 | jalingo
# Processing Record 9 of Set 7 | shebunino
# Processing Record 10 of Set 7 | mukhen
# Processing Record 11 of Set 7 | seymchan
# Processing Record 12 of Set 7 | okhotsk
# Processing Record 13 of Set 7 | tommot
# Processing Record 14 of Set 7 | susehri
# Processing Record 15 of Set 7 | oyama
# Processing Record 16 of Set 7 | san cristobal
# Processing Record 17 of Set 7 | coolum beach
# Processing Record 18 of Set 7 | richards bay
# Processing Record 19 of Set 7 | lebu
# Processing Record 20 of Set 7 | tobermory
# Processing Record 21 of Set 7 | koygorodok
# Processing Record 22 of Set 7 | lorengau
# Processing Record 23 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 7 | doha
# Processing Record 25 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 7 | santa isabel do para
# Processing Record 27 of Set 7 | birao
# Processing Record 28 of Set 7 | naze
# Processing Record 29 of Set 7 | nome
# Processing Record 30 of Set 7 | brae
# Processing Record 31 of Set 7 | price
# Processing Record 32 of Set 7 | alnashi
# Processing Record 33 of Set 7 | tura
# Processing Record 34 of Set 7 | synya
# Processing Record 35 of Set 7 | ulladulla
# Processing Record 36 of Set 7 | yaan
# Processing Record 37 of Set 7 | solnechnyy
# Processing Record 38 of Set 7 | esperance
# Processing Record 39 of Set 7 | salalah
# Processing Record 40 of Set 7 | bridlington
# Processing Record 41 of Set 7 | isangel
# Processing Record 42 of Set 7 | akyab
# Processing Record 43 of Set 7 | campoverde
# Processing Record 44 of Set 7 | kudahuvadhoo
# Processing Record 45 of Set 7 | ugoofaaru
# Processing Record 46 of Set 7 | pechenga
# Processing Record 47 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 48 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 49 of Set 7 | jalu
# Processing Record 50 of Set 7 | piacabucu
# Processing Record 1 of Set 8 | pisco
# Processing Record 2 of Set 8 | alma
# Processing Record 3 of Set 8 | puerto ayacucho
# Processing Record 4 of Set 8 | arawa
# Processing Record 5 of Set 8 | utinga
# Processing Record 6 of Set 8 | port hedland
# Processing Record 7 of Set 8 | folldal
# Processing Record 8 of Set 8 | san quintin
# Processing Record 9 of Set 8 | los amates
# Processing Record 10 of Set 8 | monatele
# City not found. Skipping...
# Processing Record 11 of Set 8 | kayes
# Processing Record 12 of Set 8 | grand gaube
# Processing Record 13 of Set 8 | champerico
# Processing Record 14 of Set 8 | chachoengsao
# Processing Record 15 of Set 8 | kaeo
# Processing Record 16 of Set 8 | kuah
# Processing Record 17 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 18 of Set 8 | formosa
# Processing Record 19 of Set 8 | shuangyang
# Processing Record 20 of Set 8 | avera
# Processing Record 21 of Set 8 | leningradskiy
# Processing Record 22 of Set 8 | zapolyarnyy
# Processing Record 23 of Set 8 | lichinga
# Processing Record 24 of Set 8 | zaysan
# Processing Record 25 of Set 8 | college
# Processing Record 26 of Set 8 | vagur
# Processing Record 27 of Set 8 | monte azul
# Processing Record 28 of Set 8 | yangambi
# Processing Record 29 of Set 8 | broome
# Processing Record 30 of Set 8 | vardo
# Processing Record 31 of Set 8 | olafsvik
# Processing Record 32 of Set 8 | grindavik
# Processing Record 33 of Set 8 | lompoc
# Processing Record 34 of Set 8 | zaraza
# Processing Record 35 of Set 8 | mount isa
# Processing Record 36 of Set 8 | quarai
# Processing Record 37 of Set 8 | omboue
# Processing Record 38 of Set 8 | srikakulam
# Processing Record 39 of Set 8 | tautira
# Processing Record 40 of Set 8 | predivinsk
# Processing Record 41 of Set 8 | amga
# Processing Record 42 of Set 8 | dayong
# Processing Record 43 of Set 8 | beachwood
# Processing Record 44 of Set 8 | chaozhou
# Processing Record 45 of Set 8 | gigmoto
# Processing Record 46 of Set 8 | santa luzia
# Processing Record 47 of Set 8 | clyde river
# Processing Record 48 of Set 8 | kysyl-syr
# Processing Record 49 of Set 8 | kitimat
# Processing Record 50 of Set 8 | gravelbourg
# Processing Record 1 of Set 9 | nha trang
# Processing Record 2 of Set 9 | safwah
# City not found. Skipping...
# Processing Record 3 of Set 9 | skibbereen
# Processing Record 4 of Set 9 | adre
# Processing Record 5 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 6 of Set 9 | nieuw amsterdam
# Processing Record 7 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 9 | zemio
# Processing Record 10 of Set 9 | dalirig
# Processing Record 11 of Set 9 | bac lieu
# Processing Record 12 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 9 | chipata
# Processing Record 14 of Set 9 | itacoatiara
# Processing Record 15 of Set 9 | bodmin
# Processing Record 16 of Set 9 | denau
# City not found. Skipping...
# Processing Record 17 of Set 9 | sibolga
# Processing Record 18 of Set 9 | nilagiri
# Processing Record 19 of Set 9 | northview
# Processing Record 20 of Set 9 | marsh harbour
# Processing Record 21 of Set 9 | wenatchee
# Processing Record 22 of Set 9 | ciudad bolivar
# Processing Record 23 of Set 9 | puerto leguizamo
# Processing Record 24 of Set 9 | novobirilyussy
# Processing Record 25 of Set 9 | la rioja
# Processing Record 26 of Set 9 | bodden town
# Processing Record 27 of Set 9 | port blair
# Processing Record 28 of Set 9 | plettenberg bay
# Processing Record 29 of Set 9 | biloxi
# Processing Record 30 of Set 9 | rosarito
# Processing Record 31 of Set 9 | buraydah
# Processing Record 32 of Set 9 | vila velha
# Processing Record 33 of Set 9 | burns lake
# Processing Record 34 of Set 9 | batticaloa
# Processing Record 35 of Set 9 | vryheid
# Processing Record 36 of Set 9 | guerrero negro
# Processing Record 37 of Set 9 | tenenkou
# Processing Record 38 of Set 9 | sitka
# Processing Record 39 of Set 9 | dunedin
# Processing Record 40 of Set 9 | prien
# Processing Record 41 of Set 9 | kruisfontein
# Processing Record 42 of Set 9 | atar
# Processing Record 43 of Set 9 | korem
# Processing Record 44 of Set 9 | pascagoula
# Processing Record 45 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 46 of Set 9 | chodziez
# Processing Record 47 of Set 9 | hibbing
# Processing Record 48 of Set 9 | talnakh
# Processing Record 49 of Set 9 | kerema
# Processing Record 50 of Set 9 | campbellsville
# Processing Record 1 of Set 10 | nanortalik
# Processing Record 2 of Set 10 | abiy adi
# City not found. Skipping...
# Processing Record 3 of Set 10 | kodiak
# Processing Record 4 of Set 10 | sao filipe
# Processing Record 5 of Set 10 | weyburn
# Processing Record 6 of Set 10 | sanming
# Processing Record 7 of Set 10 | abu dhabi
# Processing Record 8 of Set 10 | rayong
# Processing Record 9 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 10 | vestmannaeyjar
# Processing Record 11 of Set 10 | puerto escondido
# Processing Record 12 of Set 10 | saint-augustin
# Processing Record 13 of Set 10 | wajir
# Processing Record 14 of Set 10 | damietta
# Processing Record 15 of Set 10 | otradnyy
# Processing Record 16 of Set 10 | bamiantong
# Processing Record 17 of Set 10 | rehoboth
# Processing Record 18 of Set 10 | saint george
# Processing Record 19 of Set 10 | san juan
# Processing Record 20 of Set 10 | fuerte olimpo
# Processing Record 21 of Set 10 | atambua
# Processing Record 22 of Set 10 | santa cruz cabralia
# Processing Record 23 of Set 10 | tabou
# Processing Record 24 of Set 10 | tabarqah
# City not found. Skipping...
# Processing Record 25 of Set 10 | vestmanna
# Processing Record 26 of Set 10 | gorontalo
# Processing Record 27 of Set 10 | nivala
# Processing Record 28 of Set 10 | bilibino
# Processing Record 29 of Set 10 | kaminskiy
# Processing Record 30 of Set 10 | beringovskiy
# Processing Record 31 of Set 10 | shache
# Processing Record 32 of Set 10 | tynda
# Processing Record 33 of Set 10 | haines junction
# Processing Record 34 of Set 10 | zhanaozen
# Processing Record 35 of Set 10 | praia da vitoria
# Processing Record 36 of Set 10 | coihaique
# Processing Record 37 of Set 10 | progreso
# Processing Record 38 of Set 10 | samarai
# Processing Record 39 of Set 10 | pitimbu
# Processing Record 40 of Set 10 | namatanai
# Processing Record 41 of Set 10 | porbandar
# Processing Record 42 of Set 10 | durban
# Processing Record 43 of Set 10 | juchipila
# Processing Record 44 of Set 10 | wang noi
# Processing Record 45 of Set 10 | seoul
# Processing Record 46 of Set 10 | winburg
# Processing Record 47 of Set 10 | moustheni
# Processing Record 48 of Set 10 | newtonmore
# Processing Record 49 of Set 10 | salina cruz
# Processing Record 50 of Set 10 | miri
# Processing Record 1 of Set 11 | zyryanskoye
# Processing Record 2 of Set 11 | serebryansk
# Processing Record 3 of Set 11 | westport
# Processing Record 4 of Set 11 | fortuna
# Processing Record 5 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 11 | miranda
# Processing Record 7 of Set 11 | berbera
# Processing Record 8 of Set 11 | nangomba
# Processing Record 9 of Set 11 | virginia beach
# Processing Record 10 of Set 11 | nurota
# Processing Record 11 of Set 11 | kismayo
# Processing Record 12 of Set 11 | ahuimanu
# Processing Record 13 of Set 11 | guaruja
# Processing Record 14 of Set 11 | thunder bay
# Processing Record 15 of Set 11 | ruteng
# Processing Record 16 of Set 11 | kansanshi
# Processing Record 17 of Set 11 | mirina
# City not found. Skipping...
# Processing Record 18 of Set 11 | constitucion
# Processing Record 19 of Set 11 | kathu
# Processing Record 20 of Set 11 | naryshkino
# Processing Record 21 of Set 11 | mantua
# Processing Record 22 of Set 11 | front royal
# Processing Record 23 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 11 | merauke
# Processing Record 25 of Set 11 | bo
# City not found. Skipping...
# Processing Record 26 of Set 11 | xichang
# Processing Record 27 of Set 11 | los llanos de aridane
# Processing Record 28 of Set 11 | namibe
# Processing Record 29 of Set 11 | douglas
# Processing Record 30 of Set 11 | lazaro cardenas
# Processing Record 31 of Set 11 | lincoln
# Processing Record 32 of Set 11 | ostrovnoy
# Processing Record 33 of Set 11 | along
# Processing Record 34 of Set 11 | bagdarin
# Processing Record 35 of Set 11 | balkhash
# Processing Record 36 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 11 | ippy
# Processing Record 38 of Set 11 | concordia
# Processing Record 39 of Set 11 | penukonda
# Processing Record 40 of Set 11 | batemans bay
# Processing Record 41 of Set 11 | pangnirtung
# Processing Record 42 of Set 11 | kalmunai
# Processing Record 43 of Set 11 | bratsk
# Processing Record 44 of Set 11 | bud
# Processing Record 45 of Set 11 | port hawkesbury
# Processing Record 46 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 11 | sarakhs
# Processing Record 48 of Set 11 | klaksvik
# Processing Record 49 of Set 11 | ayan
# Processing Record 50 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 1 of Set 12 | thompson
# Processing Record 2 of Set 12 | njombe
# Processing Record 3 of Set 12 | wexford
# Processing Record 4 of Set 12 | sokoni
# Processing Record 5 of Set 12 | poso
# Processing Record 6 of Set 12 | verkh-usugli
# Processing Record 7 of Set 12 | taltal
# Processing Record 8 of Set 12 | fougamou
# Processing Record 9 of Set 12 | phetchabun
# Processing Record 10 of Set 12 | methoni
# Processing Record 11 of Set 12 | ensley
# Processing Record 12 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 12 | kerki
# City not found. Skipping...
# Processing Record 14 of Set 12 | alto araguaia
# Processing Record 15 of Set 12 | takhatgarh
# Processing Record 16 of Set 12 | idar
# Processing Record 17 of Set 12 | haifa
# Processing Record 18 of Set 12 | nhulunbuy
# Processing Record 19 of Set 12 | benoni
# Processing Record 20 of Set 12 | cap-haitien
# Processing Record 21 of Set 12 | chivay
# Processing Record 22 of Set 12 | mana
# Processing Record 23 of Set 12 | bousso
# Processing Record 24 of Set 12 | manga
# Processing Record 25 of Set 12 | ayer itam
# City not found. Skipping...
# Processing Record 26 of Set 12 | teya
# Processing Record 27 of Set 12 | mayor pablo lagerenza
# Processing Record 28 of Set 12 | mackay
# Processing Record 29 of Set 12 | belmonte
# Processing Record 30 of Set 12 | areia branca
# Processing Record 31 of Set 12 | bhinmal
# Processing Record 32 of Set 12 | kawalu
# Processing Record 33 of Set 12 | acari
# Processing Record 34 of Set 12 | havre-saint-pierre
# Processing Record 35 of Set 12 | ahipara
# Processing Record 36 of Set 12 | noumea
# Processing Record 37 of Set 12 | valley city
# Processing Record 38 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 12 | nicosia
# Processing Record 40 of Set 12 | saint-michel-des-saints
# Processing Record 41 of Set 12 | escanaba
# Processing Record 42 of Set 12 | jishou
# Processing Record 43 of Set 12 | bosaso
# Processing Record 44 of Set 12 | tessaoua
# Processing Record 45 of Set 12 | khandyga
# Processing Record 46 of Set 12 | sisimiut
# Processing Record 47 of Set 12 | san jeronimo
# Processing Record 48 of Set 12 | ust-nera
# Processing Record 49 of Set 12 | big bend
# Processing Record 50 of Set 12 | juniyah
# City not found. Skipping...
# Processing Record 1 of Set 13 | gladstone
# Processing Record 2 of Set 13 | klerksdorp
# Processing Record 3 of Set 13 | rio cuarto
# Processing Record 4 of Set 13 | linxia
# Processing Record 5 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 13 | jaque
# Processing Record 7 of Set 13 | hobyo
# Processing Record 8 of Set 13 | buyukcavuslu
# Processing Record 9 of Set 13 | nguruka
# Processing Record 10 of Set 13 | teguise
# Processing Record 11 of Set 13 | quesnel
# Processing Record 12 of Set 13 | dargaville
# Processing Record 13 of Set 13 | rio gallegos
# Processing Record 14 of Set 13 | kirksville
# Processing Record 15 of Set 13 | evensk
# Processing Record 16 of Set 13 | viedma
# Processing Record 17 of Set 13 | puerto del rosario
# Processing Record 18 of Set 13 | itaqui
# Processing Record 19 of Set 13 | lewistown
# Processing Record 20 of Set 13 | potsdam
# Processing Record 21 of Set 13 | murgab
# Processing Record 22 of Set 13 | saint anthony
# Processing Record 23 of Set 13 | conde
# Processing Record 24 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 25 of Set 13 | itarema
# Processing Record 26 of Set 13 | kirsanov
# Processing Record 27 of Set 13 | valparaiso
# Processing Record 28 of Set 13 | kulhudhuffushi
# Processing Record 29 of Set 13 | manado
# Processing Record 30 of Set 13 | batagay-alyta
# Processing Record 31 of Set 13 | gogrial
# Processing Record 32 of Set 13 | chincha alta
# Processing Record 33 of Set 13 | palembang
# Processing Record 34 of Set 13 | gasa
# Processing Record 35 of Set 13 | paucartambo
# City not found. Skipping...
# Processing Record 36 of Set 13 | bani walid
# Processing Record 37 of Set 13 | lagoa
# Processing Record 38 of Set 13 | alihe
# Processing Record 39 of Set 13 | dalvik
# Processing Record 40 of Set 13 | vaitape
# Processing Record 41 of Set 13 | calama
# Processing Record 42 of Set 13 | oriximina
# Processing Record 43 of Set 13 | banjar
# Processing Record 44 of Set 13 | lata
# Processing Record 45 of Set 13 | tahe
# Processing Record 46 of Set 13 | saint-francois
# Processing Record 47 of Set 13 | derzhavinsk
# Processing Record 48 of Set 13 | taree
# Processing Record 49 of Set 13 | armidale
# Processing Record 50 of Set 13 | tevaitoa
# Processing Record 1 of Set 14 | zabaykalsk
# Processing Record 2 of Set 14 | porto santo
# Processing Record 3 of Set 14 | itaituba
# Processing Record 4 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 14 | moussoro
# Processing Record 6 of Set 14 | whitehorse
# Processing Record 7 of Set 14 | pak phanang
# Processing Record 8 of Set 14 | baruun-urt
# Processing Record 9 of Set 14 | den helder
# Processing Record 10 of Set 14 | xiongshi
# City not found. Skipping...
# Processing Record 11 of Set 14 | bolshaya sosnova
# Processing Record 12 of Set 14 | owase
# Processing Record 13 of Set 14 | alta floresta
# Processing Record 14 of Set 14 | kilindoni
# Processing Record 15 of Set 14 | brigham city
# Processing Record 16 of Set 14 | urengoy
# Processing Record 17 of Set 14 | springbok
# Processing Record 18 of Set 14 | bauchi
# Processing Record 19 of Set 14 | sinnamary
# Processing Record 20 of Set 14 | hofn
# Processing Record 21 of Set 14 | kjopsvik
# Processing Record 22 of Set 14 | harper
# Processing Record 23 of Set 14 | kamyshla
# Processing Record 24 of Set 14 | boyolangu
# Processing Record 25 of Set 14 | dafeng
# Processing Record 26 of Set 14 | tigil
# Processing Record 27 of Set 14 | kurilsk
# Processing Record 28 of Set 14 | artyom
# Processing Record 29 of Set 14 | ulaangom
# Processing Record 30 of Set 14 | fonte boa
# Processing Record 31 of Set 14 | vanavara
# Processing Record 32 of Set 14 | ostrovskoye
# Processing Record 33 of Set 14 | bay roberts
# Processing Record 34 of Set 14 | yingzhong
# City not found. Skipping...
# Processing Record 35 of Set 14 | kleck
# City not found. Skipping...
# Processing Record 36 of Set 14 | kotovo
# Processing Record 37 of Set 14 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 14 | pau dos ferros
# Processing Record 39 of Set 14 | billings
# Processing Record 40 of Set 14 | mucurici
# Processing Record 41 of Set 14 | hit
# Processing Record 42 of Set 14 | heves
# Processing Record 43 of Set 14 | santana do livramento
# Processing Record 44 of Set 14 | khilok
# Processing Record 45 of Set 14 | albufeira
# Processing Record 46 of Set 14 | kashan
# Processing Record 47 of Set 14 | bathsheba
# Processing Record 48 of Set 14 | sioux lookout
# Processing Record 49 of Set 14 | bagotville
# Processing Record 50 of Set 14 | eldikan
# City not found. Skipping...
# Processing Record 1 of Set 15 | udachnyy
# Processing Record 2 of Set 15 | farmersville
# Processing Record 3 of Set 15 | ivanteyevka
# Processing Record 4 of Set 15 | tukrah
# Processing Record 5 of Set 15 | trojes
# Processing Record 6 of Set 15 | ambovombe
# Processing Record 7 of Set 15 | tessalit
# Processing Record 8 of Set 15 | puerto penasco
# Processing Record 9 of Set 15 | singaraja
# Processing Record 10 of Set 15 | pitea
# Processing Record 11 of Set 15 | sharjah
# Processing Record 12 of Set 15 | harku
# Processing Record 13 of Set 15 | gleisdorf
# Processing Record 14 of Set 15 | hokitika
# Processing Record 15 of Set 15 | nizhniy baskunchak
# Processing Record 16 of Set 15 | novikovo
# Processing Record 17 of Set 15 | esna
# Processing Record 18 of Set 15 | nuuk
# Processing Record 19 of Set 15 | worthington
# Processing Record 20 of Set 15 | potgietersrus
# City not found. Skipping...
# Processing Record 21 of Set 15 | craig
# Processing Record 22 of Set 15 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 23 of Set 15 | blagoevgrad
# Processing Record 24 of Set 15 | nakamura
# Processing Record 25 of Set 15 | goedereede
# Processing Record 26 of Set 15 | grandview
# Processing Record 27 of Set 15 | asau
# Processing Record 28 of Set 15 | pacifica
# Processing Record 29 of Set 15 | phan thiet
# Processing Record 30 of Set 15 | taga
# Processing Record 31 of Set 15 | alamogordo
# Processing Record 32 of Set 15 | corralillo
# Processing Record 33 of Set 15 | tsumeb
# Processing Record 34 of Set 15 | kitami
# Processing Record 35 of Set 15 | verkhoyansk
# Processing Record 36 of Set 15 | saint-leu
# Processing Record 37 of Set 15 | road town
# Processing Record 38 of Set 15 | ano komi
# Processing Record 39 of Set 15 | sturgeon bay
# Processing Record 40 of Set 15 | santarem
# Processing Record 41 of Set 15 | verkhnyaya toyma
# Processing Record 42 of Set 15 | kota kinabalu
# Processing Record 43 of Set 15 | srednekolymsk
# Processing Record 44 of Set 15 | russkiy aktash
# Processing Record 45 of Set 15 | antofagasta
# Processing Record 46 of Set 15 | jumla
# Processing Record 47 of Set 15 | isla vista
# Processing Record 48 of Set 15 | tezpur
# Processing Record 49 of Set 15 | buzmeyin
# Processing Record 50 of Set 15 | kita
# Processing Record 1 of Set 16 | murray bridge
# Processing Record 2 of Set 16 | zhigansk
# Processing Record 3 of Set 16 | cabo rojo
# Processing Record 4 of Set 16 | sao joao da barra
# Processing Record 5 of Set 16 | miles city
# Processing Record 6 of Set 16 | zima
# Processing Record 7 of Set 16 | wagar
# Processing Record 8 of Set 16 | tombouctou
# Processing Record 9 of Set 16 | nizwa
# Processing Record 10 of Set 16 | port hardy
# Processing Record 11 of Set 16 | neuquen
# Processing Record 12 of Set 16 | altar
# Processing Record 13 of Set 16 | bambanglipuro
# Processing Record 14 of Set 16 | lufilufi
# Processing Record 15 of Set 16 | adzope
# Processing Record 16 of Set 16 | egvekinot
# Processing Record 17 of Set 16 | hwange
# Processing Record 18 of Set 16 | chimbote
# Processing Record 19 of Set 16 | gejiu
# Processing Record 20 of Set 16 | praya
# Processing Record 21 of Set 16 | vanderhoof
# Processing Record 22 of Set 16 | pangody
# Processing Record 23 of Set 16 | dakar
# Processing Record 24 of Set 16 | kushmurun
# Processing Record 25 of Set 16 | carballo
# Processing Record 26 of Set 16 | fort myers beach
# Processing Record 27 of Set 16 | corrente
# Processing Record 28 of Set 16 | sao pedro do sul
# Processing Record 29 of Set 16 | cap-aux-meules
# Processing Record 30 of Set 16 | gubkinskiy
# Processing Record 31 of Set 16 | brest
# Processing Record 32 of Set 16 | fremont
# Processing Record 33 of Set 16 | severobaykalsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Soltsy  58.1239   30.3238     30.13        94         100
# 1  Norman Wells  65.2820 -126.8329     -2.16        84          75
# 2        Touros  -5.1989  -35.4608     85.10        62          31
# 3        Albany  42.6001  -73.9662     25.81        52          75
# 4  Punta Arenas -53.1500  -70.9167     60.12        55          29
# 5    Butaritari   3.0707  172.7902     81.36        79          24
# 6         Airai  -8.9266  125.4092     61.39        90          84
# 7       Rikitea -23.1203 -134.9692     78.08        77          27
# 8         Dubbo -32.2500  148.6167     68.13        83          75
# 9     Busselton -33.6500  115.3333     59.09        74           0
#
#    Wind Speed Country       Description
# 0       10.07      RU   overcast clouds
# 1        3.44      CA        light snow
# 2       12.41      BR        light rain
# 3        1.99      US     broken clouds
# 4        3.69      CL  scattered clouds
# 5       13.96      KI        few clouds
# 6        3.02      TL     broken clouds
# 7       19.24      PF        light rain
# 8        8.05      AU     broken clouds
# 9       11.79      AU         clear sky

# %%
city_data_df.count()
# Out:
# City           719
# Lat            719
# Lng            719
# Max Temp       719
# Humidity       719
# Cloudiness     719
# Wind Speed     719
# Country        719
# Description    719
# dtype: int64

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
#Export the city data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
